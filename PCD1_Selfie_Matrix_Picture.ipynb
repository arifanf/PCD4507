# %% [markdown]
# <a href="https://colab.research.google.com/github/arifanf/PCD4507/blob/main/PCD1_Selfie_Matrix_Picture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Arifa Nurul Fadlila <br>
# NIM : A11.2019.121.60 <br>
# Kelompok : A11.4507

# %% [markdown]
# ### Step 1 : Import Libraries

# %%
import numpy as np
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display

# %% [markdown]
# ### Step 2 : Read Image

# %%
image = cv.imread('/content/test.jpg')

# %% [markdown]
# ### Step 3 : Show Image

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=720x1280 at 0x7FB27E02A110>

# %% [markdown]
# ### Step 4 : Convert to Array Matrix

# %%
npdata = np.asarray(image) # convert image to numpy array
  
# data
print(npdata)
# Out:
# [[[189 215 229]
#   [189 215 229]
#   [189 215 229]
#   ...
#   [ 11   9   9]
#   [  8   8   8]
#   [  7   7   7]]
#
#  [[189 215 229]
#   [189 215 229]
#   [189 215 229]
#   ...
#   [  8   8   8]
#   [  7   7   7]
#   [  6   6   6]]
#
#  [[188 215 229]
#   [188 215 229]
#   [188 215 229]
#   ...
#   [  6   6   6]
#   [  5   5   5]
#   [  3   5   5]]
#
#  ...
#
#  [[ 15  25   2]
#   [ 16  26   3]
#   [ 19  27   4]
#   ...
#   [ 14   7  98]
#   [ 18   9 113]
#   [ 20  12 119]]
#
#  [[ 15  25   2]
#   [ 16  26   3]
#   [ 19  27   4]
#   ...
#   [ 12   6  95]
#   [ 15   7 108]
#   [ 17   7 113]]
#
#  [[ 15  25   2]
#   [ 16  26   3]
#   [ 19  27   4]
#   ...
#   [ 11   5  94]
#   [ 14   4 104]
#   [ 13   3 109]]]

# %%
print(type(npdata))
  
#  shape
print(npdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (1280, 720, 3)

# %% [markdown]
# ### Thank You
